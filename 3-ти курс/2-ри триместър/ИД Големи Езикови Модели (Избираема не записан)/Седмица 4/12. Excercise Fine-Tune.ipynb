# %% [markdown]
# # Fine-Tune BERT, T5 and llama 3.2 on [CINEXIO](https://www.mdpi.com/2673-4117/5/4/152) for example with Metrics

# %% [markdown]
# Use other Models, not only the examples and other Metrics, not only the example.

# %% [markdown]
# ### Fine-Tune for [sentiment analysis](https://www.geeksforgeeks.org/dataset-for-sentiment-analysis/?utm_source=chatgpt.com) (classification task, e.g. [BGGLUE](https://bgglue.github.io/tasks/) datasets)

# %% [markdown]
# 1. **Download the Dataset**: Access the dataset from Kaggle using the provided link.​
#
# 2. **Prepare the Dataset**: Load and preprocess the dataset to fit the input requirements of your chosen model.​
#
# 3. **Fine-Tune the Model**: Utilize the code provided earlier to fine-tune your selected model on the preprocessed *CLEF* dataset.

# %% [markdown]
# Extra: [CLEF](https://www.kaggle.com/datasets/tngthanhle/clef-dataset)
