# %% [markdown]
# # 1. Hello World:

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # 2. Variables and arithmetic:

# %%
a = 10
b = 5
c = a + b # -, *, / etc.
print(c)
# Out:
# 15

# %% [markdown]
# # 3. User input:

# %%
name = input("Enter your name: ")
print("Hello, " + name)
# Out:
# Enter your name: lady gaga
# Hello, lady gaga

# %% [markdown]
# # 4. Conditional statement:

# %%
#num = 7
num = int(input("Input number: ")) # convert
#num = input("Input number: ")

if num > 0:
    print("Positive number")
elif num == 0:
    print("Zero")
else:
    print("Negative number")
# Out:
# Input number: 0
# Zero

# %% [markdown]
# # 5. Loop:

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # 6. List manipulation:

# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %% [markdown]
# # 7. String manipulation:

# %%
sentence = "Python is awesome!"
print(sentence.upper())
print(sentence.split())
# Out:
# PYTHON IS AWESOME!
# ['Python', 'is', 'awesome!']

# %% [markdown]
# # 8. Dictionary:

# %%
person = {"name": "John Doe", "age": 34, "city": "New York"}

print(person["name"], person["age"], person["city"])
#print(person["name"], ["age"], ["city"])
# Out:
# John Doe 34 New York

# %% [markdown]
# # 9. Functions:

# %%
def square(x):
    return x ** 2

print(square(5))


def add(a, b):
    return a + b

print(add(36.6, 36.6))
# Out:
# 25
# 73.2

# %% [markdown]
# # 10. File handling:

# %%
file = open("example.txt", "w")
file.write("Hello, World! /nHI!")
file.close()

# %% [markdown]
# # 11. Exception handling:

# %%
try:
    num = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero...")
# Out:
# Cannot divide by zero...

# %% [markdown]
# # 12. Regular expressions:

# %%
import re

text = "Hello, my email is example@examplemail.com"
pattern = r'\w+@\w+\.\w+'
match = re.search(pattern, text)
print(match.group(0))
# Out:
# example@examplemail.com

# %% [markdown]
# # 13. List comprehension:

# %%
numbers = [1, 2, 3, 4, 5]
squared = [x ** 2 for x in numbers]
print(squared)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# # 14. Lambda functions:

# %%
multiply = lambda x, y: x * y
print(multiply(3, 4)) # argumets
# Out:
# 12

# %% [markdown]
# # 15. Date and time:

# %%
import datetime

now = datetime.datetime.now()
print(now)
# Out:
# 2025-04-11 13:10:42.047149

# %% [markdown]
# # 16. Random numbers:

# %%
import random

number = random.randint(1, 10)
print(number)
# Out:
# 5

# %% [markdown]
# # 17. JSON handling:

# %%
import json

data = '{"name": "Jane Doe", "age": 33}'
person = json.loads(data)
print(person["name"], person["age"])
# Out:
# Jane Doe 33

# %% [markdown]
# # 18. Web scraping with Beautiful Soup:

# %%
import requests
from bs4 import BeautifulSoup

url = "https://duckduckgo.com"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
title = soup.title.string
print(title)
# Out:
# DuckDuckGo - Protection. Privacy. Peace of mind.

# %% [markdown]
# # 19. Class:

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        return f"Hello, my name is {self.name} and I am {self.age} years old."

# Usage:
p = Person("Alisson", 25)
print(p.greet())
# Out:
# Hello, my name is Alisson and I am 25 years old.
